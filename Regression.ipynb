# %% [markdown]
# Regression - Breast Cancer Gene Expression Profiles (METABRIC)

# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 66.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 81.2 MB/s eta 0:00:00
# ...

# %%
pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 93.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 10.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 39.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 36.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 10.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a54310fc-ca3a-4172-831e-bf6b19a8a34c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a54310fc-ca3a-4172-831e-bf6b19a8a34c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv("mutation.csv")
data.head()
# Out:
#    patient_id  age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 0           0             75.65             MASTECTOMY  Breast Cancer
# 1           2             43.19      BREAST CONSERVING  Breast Cancer
# 2           5             48.87             MASTECTOMY  Breast Cancer
# 3           6             47.68             MASTECTOMY  Breast Cancer
# 4           8             76.97             MASTECTOMY  Breast Cancer
#
#                         cancer_type_detailed cellularity  chemotherapy  \
# 0           Breast Invasive Ductal Carcinoma         NaN             0
# 1           Breast Invasive Ductal Carcinoma        High             0
# 2           Breast Invasive Ductal Carcinoma        High             1
# 3  Breast Mixed Ductal and Lobular Carcinoma    Moderate             1
# 4  Breast Mixed Ductal and Lobular Carcinoma        High             1
#
#   pam50_+_claudin-low_subtype  cohort er_status_measured_by_ihc  ...  \
# ...

# %%
from pycaret.regression import *
initial_setup = setup(data, target = 'nottingham_prognostic_index', use_gpu = True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ef737 th {
#   text-align: left;
# }
# ...

# %%
plot_model(best_model, plot = 'residuals')

# %%
plot_model(best_model, plot = 'error')

# %%
plot_model(best_model, plot = 'feature')

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_42863" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42863_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_42863_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_42863_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_42863_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_42863_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_42863_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_42863_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42863_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42863_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_42863_row0_col1" class="data row0 col1" >0.0502</td>
# ...

# %%
predict.head()
# Out:
#       patient_id  age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 42           116         42.549999             MASTECTOMY  Breast Cancer
# 1702        7037         68.739998      BREAST CONSERVING  Breast Cancer
# 1400        5490         65.309998             MASTECTOMY  Breast Cancer
# 1422        5530         50.610001             MASTECTOMY  Breast Cancer
# 1814        7168         60.330002             MASTECTOMY  Breast Cancer
#
#                    cancer_type_detailed cellularity  chemotherapy  \
# 42    Breast Invasive Lobular Carcinoma    Moderate             1
# 1702   Breast Invasive Ductal Carcinoma    Moderate             0
# 1400   Breast Invasive Ductal Carcinoma        High             0
# 1422   Breast Invasive Ductal Carcinoma         Low             0
# 1814   Breast Invasive Ductal Carcinoma         Low             0
#
#      pam50_+_claudin-low_subtype  cohort er_status_measured_by_ihc  ...  \
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_b4d50_row10_col0, #T_b4d50_row10_col1, #T_b4d50_row10_col2, #T_b4d50_row10_col3, #T_b4d50_row10_col4, #T_b4d50_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b4d50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4d50_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b4d50_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b4d50_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b4d50_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b4d50_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b4d50_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
lr_predict = predict_model(lr)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf578" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf578_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bf578_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bf578_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bf578_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bf578_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bf578_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bf578_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf578_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf578_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_bf578_row0_col1" class="data row0 col1" >0.4500</td>
# ...

# %%
new_data = data.copy()
new_data.drop('nottingham_prognostic_index', axis=1, inplace=True)
new_data.head()
# Out:
#    patient_id  age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 0           0             75.65             MASTECTOMY  Breast Cancer
# 1           2             43.19      BREAST CONSERVING  Breast Cancer
# 2           5             48.87             MASTECTOMY  Breast Cancer
# 3           6             47.68             MASTECTOMY  Breast Cancer
# 4           8             76.97             MASTECTOMY  Breast Cancer
#
#                         cancer_type_detailed cellularity  chemotherapy  \
# 0           Breast Invasive Ductal Carcinoma         NaN             0
# 1           Breast Invasive Ductal Carcinoma        High             0
# 2           Breast Invasive Ductal Carcinoma        High             1
# 3  Breast Mixed Ductal and Lobular Carcinoma    Moderate             1
# 4  Breast Mixed Ductal and Lobular Carcinoma        High             1
#
#   pam50_+_claudin-low_subtype  cohort er_status_measured_by_ihc  ...  \
# ...

# %%
lr_predict = predict_model(lr, data = new_data)
lr_predict.head()
# Out:
#    patient_id  age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 0           0         75.650002             MASTECTOMY  Breast Cancer
# 1           2         43.189999      BREAST CONSERVING  Breast Cancer
# 2           5         48.869999             MASTECTOMY  Breast Cancer
# 3           6         47.680000             MASTECTOMY  Breast Cancer
# 4           8         76.970001             MASTECTOMY  Breast Cancer
#
#                         cancer_type_detailed cellularity  chemotherapy  \
# 0           Breast Invasive Ductal Carcinoma         NaN             0
# 1           Breast Invasive Ductal Carcinoma        High             0
# 2           Breast Invasive Ductal Carcinoma        High             1
# 3  Breast Mixed Ductal and Lobular Carcinoma    Moderate             1
# 4  Breast Mixed Ductal and Lobular Carcinoma        High             1
#
#   pam50_+_claudin-low_subtype  cohort er_status_measured_by_ihc  ...  \
# ...

# %%
save_model = save_model(lr, 'lr_mutation')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
lr_mutation = load_model('lr_mutation')
lr_mutation
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['patient_id', 'age_at_diagnosis',
#                                              'chemotherapy', 'cohort',
#                                              'neoplasm_histologic_grade',
#                                              'hormone_therapy',
#                                              'lymph_nodes_examined_positive',
#                                              'mutation_count',
#                                              'overall_survival_months',
#                                              'overall_survival',
#                                              'radio_therapy'],
#                                     transformer=SimpleImputer())),
#                 ('...
#                                     transformer=OneHotEncoder(cols=['cancer_type_detailed',
# ...

# %%
create_app(lr_mutation)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
